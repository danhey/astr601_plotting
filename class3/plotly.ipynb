# %%
import plotly.express as px

df = px.data.iris()

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
fig = px.scatter(
    df, x="sepal_width", y="sepal_length", color="species", symbol="species"
)
fig.show()

# %%
import plotly.express as px

df = px.data.iris()
fig = px.scatter(
    df,
    x="sepal_width",
    y="sepal_length",
    color="species",
    marginal_y="violin",
    marginal_x="box",
    trendline="ols",
    template="simple_white",
)
fig.show()

# %%
import plotly.graph_objects as go
import numpy as np

N = 100000
fig = go.Figure(
    data=go.Scattergl(
        x=np.random.randn(N),
        y=np.random.randn(N),
        mode="markers",
        marker=dict(color=np.random.randn(N), colorscale="Viridis", line_width=1),
    )
)

fig.show()

# %%
import plotly.express as px

df = px.data.election()
fig = px.scatter_3d(
    df,
    x="Joly",
    y="Coderre",
    z="Bergeron",
    color="winner",
    size="total",
    hover_name="district",
    symbol="result",
    color_discrete_map={"Joly": "blue", "Bergeron": "green", "Coderre": "red"},
)
fig.show()

# %%
# import lightkurve as lk

# lc = (
#     lk.search_lightcurve("beta Pic", mission="TESS", exptime=120, author="SPOC")[[0]]
#     .download_all(quality_bitmask="hardest")
#     .stitch()
#     .remove_nans()
# )
# x, y = lc.time.value, np.array(lc.flux.value)
# np.savetxt("data/bpic.txt", list(zip(x, y)))

# %%
x, y = np.loadtxt("data/bpic.txt").T
plt.plot(x, y)
plt.xlabel("Time")
plt.ylabel("Flux")
# Out:
# Text(0, 0.5, 'Flux')

# %%
px.line(x=x, y=y, labels={"x": "time", "y": "flux"})

# %%
# Example HRD

# %%
df = pd.read_csv("data/hrd_chara2.csv").drop_duplicates("HD ID")

# %%
plt.scatter(
    (df["Teff [K]"]),
    np.log10(df["Luminosity [L_sun]"]),
    s=np.sqrt(df["Radius [R_sun]"]) * 10 + 50,
    edgecolor="white",
    linewidth=0.1,
    alpha=0.9,
    c=1 / df["Parallax [mas]"],
    cmap="plasma",
)
# plt.xscale("log")
plt.xlim(10000, 2500)
plt.colorbar(aspect=50, pad=0.0, label="Distance [kpc]")
plt.xlabel("Teff [K]")
plt.ylabel("log10 Luminosity (L/L_sun)")
# Out:
# Text(0, 0.5, 'log10 Luminosity (L/L_sun)')

# %%
df["log_lum"] = np.log10(df["Luminosity [L_sun]"])
df["dist"] = 1 / df["Parallax [mas]"]
df["size"] = np.sqrt(df["Radius [R_sun]"]) * 10 + 50

# %%
fig = px.scatter(
    df,
    x="Teff [K]",
    y="log_lum",
    size="size",
    color="dist",
    width=1000,
    height=1000,
    opacity=1,
    labels={"log_lum": r"log10 Luminosity"},
)

# Set x and y limits
fig.update_xaxes(range=[10000, 2000])
fig.update_yaxes(range=[-3, 6])

# %%
df
# Out:
#         HD ID      Main ID      HIP ID     HR ID             RA  \
# 0     HD28307  * tet01 Tau   HIP 20885  HR  1411  04 28 34.4979
# 1    HD102212    * nu. Vir   HIP 57380  HR  4517  11 45 51.5595
# 2    HD219215    * phi Aqr  HIP 114724  HR  8834  23 14 19.3582
# 3    HD223075    *  19 Psc  HIP 117245  HR  9004  23 46 23.5164
# 4     HD99998      * e Leo   HIP 56127  HR  4432  11 30 18.8933
# ..        ...          ...         ...       ...            ...
# 689  HD182736    HD 182736   HIP 95362       NaN  19 24 03.3792
# 690  HD185351    HD 185351   HIP 96459  HR  7468  19 36 37.9768
# 691  HD188512    * bet Aql   HIP 98036  HR  7602  19 55 18.7928
# 692  HD189349    HD 189349   HIP 98269       NaN  19 58 02.3821
# 693       NaN     Wolf 437   HIP 62452       NaN  12 47 56.6245
#
#                DEC   Spectral Type                          GAIA  \
# 0    +15 57 44.221     G9IIIFe-0.5  Gaia DR3 3312748824193704832
# ...

# %%
fig = px.scatter(
    df,
    x="Teff [K]",
    y="log_lum",
    size="size",
    hover_name="Main ID",
    hover_data=["Exoplanet Host?", "Spectral Type", "ra_deg", "dec_deg"],
    color="dist",
    width=1000,
    height=1000,
    opacity=1,
    labels={"log_lum": r"log10 Luminosity"},
)

# Set x and y limits
fig.update_xaxes(range=[10000, 2000])
fig.update_yaxes(range=[-3, 6])

# %%
fig.write_html("my_cool_figure.html")
